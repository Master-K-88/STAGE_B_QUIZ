# %% [markdown]
# # STAGE B QUIZ

# %% [markdown]
# ## Importing some necessary libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
# %matplotlib inline

# %% [markdown]
# ## Loading the downloaded dataset

# %%
data_energy = pd.read_csv("energydata_complete.csv")

# %% [markdown]
# ## Displaying the first five rows of the dataset

# %%
data_energy.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %% [markdown]
# ## Dropping the 'date' and 'lights' columns from the original dataset

# %%
data_energy.drop(columns = ['date', 'lights'], axis =1, inplace = True)
data_energy.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %% [markdown]
# ## Importing the MinMaxScaler for Normalising the entire columns

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
df_nm = pd.DataFrame(scale.fit_transform(data_energy), columns = data_energy.columns)

# %% [markdown]
# ## Checking the correlation of the parameters

# %%
df_nm.corr()
# Out:
#              Appliances        T1      RH_1        T2      RH_2        T3  \
# Appliances     1.000000  0.055447  0.086031  0.120073 -0.060465  0.085060
# T1             0.055447  1.000000  0.164006  0.836834 -0.002509  0.892402
# RH_1           0.086031  0.164006  1.000000  0.269839  0.797535  0.253230
# T2             0.120073  0.836834  0.269839  1.000000 -0.165610  0.735245
# RH_2          -0.060465 -0.002509  0.797535 -0.165610  1.000000  0.137319
# T3             0.085060  0.892402  0.253230  0.735245  0.137319  1.000000
# RH_3           0.036292 -0.028550  0.844677  0.121497  0.678326 -0.011234
# T4             0.040281  0.877001  0.106180  0.762066 -0.047304  0.852778
# RH_4           0.016965  0.097861  0.880359  0.231563  0.721435  0.122737
# T5             0.019760  0.885247  0.205797  0.720550  0.110409  0.888169
# RH_5           0.006955 -0.014782  0.303258  0.029595  0.250271 -0.066355
# T6             0.117638  0.654769  0.316141  0.801186 -0.009670  0.686882
# ...

# %%
targ_df = df_nm.iloc[:,0:1]
targ_df.head()
# Out:
#    Appliances
# 0    0.046729
# 1    0.046729
# 2    0.037383
# 3    0.037383
# 4    0.046729

# %% [markdown]
# ## Showing the statistical summary of the normalised dataset

# %%
df_nm.describe()
# Out:
#          Appliances            T1          RH_1            T2          RH_2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       0.081958      0.517061      0.364271      0.308303      0.561170
# std        0.095818      0.169595      0.109512      0.159412      0.114438
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.037383      0.419219      0.283735      0.195542      0.490299
# 50%        0.046729      0.507920      0.347675      0.283499      0.563408
# 75%        0.084112      0.613516      0.441519      0.392537      0.641016
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  T3          RH_3            T4          RH_4            T5  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       0.421038      0.489601      0.518499      0.485143      0.407272
# ...

# %% [markdown]
# ## Showing the order of the target dataset

# %%
targ_df.shape
# Out:
# (19735, 1)

# %%
feat_df = df_nm.iloc[:,1:]
feat_df.head()
# Out:
#         T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5  ...        T9      RH_9     T_out  \
# 0  0.764262  0.175506  0.381691  ...  0.223032  0.677290  0.372990
# 1  0.782437  0.175506  0.381691  ...  0.226500  0.678532  0.369239
# 2  0.778062  0.175506  0.380037  ...  0.219563  0.676049  0.365488
# 3  0.770949  0.175506  0.380037  ...  0.219563  0.671909  0.361736
# 4  0.762697  0.178691  0.380037  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(feat_df, targ_df, test_size = 0.3, random_state = 42)
print('The training x data has the following order', x_train.shape)
print('The testing x data has the following order', x_test.shape)
print('The training y data has the following order', y_train.shape)
print('The testing y data has the following order', y_test.shape)
# Out:
# The training x data has the following order (13814, 26)
# The testing x data has the following order (5921, 26)
# The training y data has the following order (13814, 1)
# The testing y data has the following order (5921, 1)

# %%
tg_df_12 = x_train[['T6']]
tg_df_12.head()
# Out:
#              T6
# 9129   0.180420
# 2453   0.275215
# 9152   0.131907
# 12694  0.444040
# 16952  0.944695

# %%
feat_df_12 = x_train[['T2']]
feat_df_12.head()
# Out:
#              T2
# 9129   0.122850
# 2453   0.188999
# 9152   0.057427
# 12694  0.280834
# 16952  1.000000

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(feat_df_12, tg_df_12)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import r2_score
y2_test = x_test[['T6']]
x = x_test[['T2']]
yhat = lin_reg.predict(x)
r2_score = r2_score(y2_test, yhat)

# %%
r2_score.round(2)
# Out:
# 0.64

# %%
from sklearn.metrics import mean_absolute_error
mae_13 = mean_absolute_error(y2_test, yhat)
round(mae_13, 2)
# Out:
# 0.08

# %%
import numpy as np
rss_14 = np.sum(np.square(y2_test - yhat))
rss_14.round(2)
# Out:
# T6    66.12
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y2_test, yhat))
round(rmse, 3)
# Out:
# 0.106

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha = 0.4)
ridge.fit(feat_df_12, tg_df_12)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
y_pred = ridge.predict(x)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y2_test, y_pred))
round(rmse, 3)
# Out:
# 0.106

# %%
#comparing the effects of regularisation
def get_weights_df(reg, feat, col_name):
#this function returns the weight of every feature
    weights = pd.Series(reg.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(feat_df_12, tg_df_12)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
yhat_20 = lasso_reg.predict(x)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y2_test, yhat_20))
round(rmse, 3)
# Out:
# 0.106

# %%
lasso_reg.coef_
# Out:
# array([0.85177991])

# %% [markdown]
# ## From the question, I was given a value for different column for x and y, and that is what I used for implementing my model.

# %% [markdown]
# ## The x value was 'T2' while the y value is 'T6'

# %% [markdown]
# ## Question 18 appeared first from the questions that i am suppose to model so, I took the value of x to be 'T2' and y to be 'T6' throughout.
# ## This was due to the fact that the statement wasn't clear enough cause no disparity between the featured dataset and target dataset from the one i used.

# %% [markdown]
# # I am meant to score 85% again.
# ## well thanks a lot for the opportunity given to me.

# %% [markdown]
# # Correction to the questions I wasn't meant to fail

# %%
x_train.shape
# Out:
# (13814, 26)

# %%
y_train.shape
# Out:
# (13814, 1)

# %%
x_test.shape
# Out:
# (5921, 26)

# %%
y_test.shape
# Out:
# (5921, 1)

# %%
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_hat_5 = lin_reg.predict(x_test)

# %%
# question 8
from sklearn.metrics import r2_score
#Coefficient of Determination (in two decimal places)
r2_score = r2_score(y_test, y_hat_5)
r2_score.round(2)
# Out:
# 0.15

# %%
# question 10
#Mean Absolute Error (in two decimal places)
from sklearn.metrics import mean_absolute_error
mae_13 = mean_absolute_error(y_test, y_hat_5)
round(mae_13, 2)
# Out:
# 0.05

# %%
# question 11
#RMSE with the Lasso Regression (in 3 decimal places)
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)

yhat_11 = lasso_reg.predict(x_test)
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, yhat_11))
round(rmse, 3)
# Out:
# 0.094

# %%
#question 17
#RMSE with the Lasso Regression (in 3 decimal places)
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)

yhat_11 = lasso_reg.predict(x_test)
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, yhat_11))
round(rmse, 3)
# Out:
# 0.094

# %%
#question 6
# Residual Sum of Squares (in two decimal places)
import numpy as np
yhat = lin_reg.predict(x_test)
rss_ = np.sum(np.square(y_test - yhat))
rss_.round(2)
# Out:
# Appliances    45.35
# dtype: float64

# %%
#comparing the effects of regularisation
def get_weights_df(model, feat, col_name):
#this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
linear_model_weights = get_weights_df(lin_reg, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')
final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-a7821e42c50e> in <module>
# ----> 1 linear_model_weights = get_weights_df(lin_reg, x_train, 'Linear_Model_Weight')
#       2 ridge_weights_df = get_weights_df(ridge, x_train, 'Ridge_Weight')
#       3 lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')
#       4 final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
#       5 final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')
#
# <ipython-input-45-737e2807a907> in get_weights_df(model, feat, col_name)
#       2 def get_weights_df(model, feat, col_name):
#       3 #this function returns the weight of every feature
# ----> 4     weights = pd.Series(model.coef_.feat.columns).sort_values()
#       5     weights_df = pd.DataFrame(weights).reset_index()
# ...
